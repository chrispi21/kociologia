# %% [markdown]
# <a href="https://colab.research.google.com/github/chrispi21/kociologia/blob/master/01_typy_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deklarowanie zmiennych - przypomnienie

# %%
# deklaracja zmiennej typu int
x = 7

# %%
# sprawdzenie typu zmiennej
type(x)

# %%
# sprawdzenie, czy x jest instancją int
isinstance(x, int)

# %%
# sprawdzenie adresu zmiennej w pamięci
id(x)

# %% [markdown]
# Ćwiczenie
#
# Utwórz zmienną o dowolnej nazwie i wartości `7.0`. Jakiego typu jest ta zmienna? Co zwraca funkcja `id`?

# %%
#@title Rozwiązanie
y = 7.0
print(type(y))
print(id(y))
